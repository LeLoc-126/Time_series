# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Paris,France 2023-10-01 to 2024-11-10.csv')

# %%
df.head()
# Out:
#            name   datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  Paris,France 2023-10-01     26.5     12.5  18.9          26.5
# 1  Paris,France 2023-10-02     27.7     14.5  20.7          27.9
# 2  Paris,France 2023-10-03     22.1     15.0  18.8          22.1
# 3  Paris,France 2023-10-04     18.2     10.2  14.2          18.2
# 4  Paris,France 2023-10-05     19.8     11.0  14.7          19.8
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          12.5       18.9  13.7      74.3  ...          3.5        3
# 1          14.5       20.7  14.7      71.0  ...          4.4        4
# 2          15.0       18.8  13.0      69.9  ...          4.8        4
# 3          10.2       14.2   9.3      73.2  ...          5.1        4
# 4          11.0       14.7   9.4      72.1  ...          3.5        3
#
#    severerisk              sunrise               sunset  moonphase  \
# 0         NaN  2023-10-01T07:49:34  2023-10-01T19:30:27       0.57
# ...

# %% [markdown]
# # 1. df preprocessing

# %%
df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')
df.dtypes
# Out:
# name                        object
# datetime            datetime64[ns]
# tempmax                    float64
# tempmin                    float64
# temp                       float64
# feelslikemax               float64
# feelslikemin               float64
# feelslike                  float64
# dew                        float64
# humidity                   float64
# precip                     float64
# precipprob                   int64
# precipcover                float64
# preciptype                  object
# snow                       float64
# snowdepth                  float64
# windgust                   float64
# windspeed                  float64
# winddir                    float64
# sealevelpressure           float64
# cloudcover                 float64
# visibility                 float64
# solarradiation             float64
# solarenergy                float64
# uvindex                      int64
# severerisk                 float64
# sunrise                     object
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['datetime'], df['temp'], color='blue')
plt.title("Paris temperature")
plt.xlabel("Time")
plt.ylabel("Temperature (°C)")
plt.grid()
plt.show()

# %% [markdown]
# # 2: df analyst

# %%
df.describe()
# Out:
#                   datetime     tempmax     tempmin        temp  feelslikemax  \
# count                  407  407.000000  407.000000  407.000000    407.000000
# mean   2024-04-21 00:00:00   16.747174   10.119165   13.266093     16.503194
# min    2023-10-01 00:00:00   -1.300000   -4.100000   -1.800000     -5.500000
# 25%    2024-01-10 12:00:00   11.800000    7.000000    9.500000     11.800000
# 50%    2024-04-21 00:00:00   16.300000   10.200000   13.100000     16.300000
# 75%    2024-07-31 12:00:00   21.600000   13.350000   17.100000     21.600000
# max    2024-11-10 00:00:00   36.200000   21.200000   28.300000     39.000000
# std                    NaN    6.689525    4.925297    5.670868      7.213525
#
#        feelslikemin   feelslike         dew    humidity      precip  ...  \
# count    407.000000  407.000000  407.000000  407.000000  407.000000  ...
# mean       9.048894   12.646683    8.984029   77.173956    2.150612  ...
# ...

# %% [markdown]
# # 3. Numerical features and categorical features.

# %% [markdown]
# # 4. Model

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

trainset = df[(df['datetime'] >= '2023-10-01') & (df['datetime'] <= '2024-09-15')]
testset = df[df['datetime'] > '2024-09-15']

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(trainset['temp'])  
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: -2.538341699833459
# p-value: 0.10642184218869566
